# %% [markdown]
# <a href="https://colab.research.google.com/github/AloysiusChua0822/ISEPub/blob/main/Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def translate_point(x, y, translate_x, translate_y):
    new_x = x + translate_x
    new_y = y + translate_y

    return new_x, new_y

x = float(input("Enter the X-coordinate of the point: "))
y = float(input("Enter the Y-coordinate of the point: "))

translate_x = float(input("Enter the translation along the X-axis: "))
translate_y = float(input("Enter the translation along the Y-axis: "))

new_x, new_y = translate_point(x, y, translate_x, translate_y)

print(f"Original Point: ({x}, {y})")
print(f"Translated Point: ({new_x}, {new_y})")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-00942bf3980d> in <cell line: 7>()
#       5     return new_x, new_y
#       6
# ----> 7 x = float(input("Enter the X-coordinate of the point: "))
#       8 y = float(input("Enter the Y-coordinate of the point: "))
#       9
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

def draw_line(x1, y1, x2, y2):
    # Plotting the points
    plt.plot([x1, x2], [y1, y2], marker='o')


    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Line between two points')


    plt.show()

# for input coord
x1 = float(input("Enter the X-coordinate of the first point: "))
y1 = float(input("Enter the Y-coordinate of the first point: "))
x2 = float(input("Enter the X-coordinate of the second point: "))
y2 = float(input("Enter the Y-coordinate of the second point: "))


draw_line(x1,y1,x2,y2)
# Out:
# Enter the X-coordinate of the first point: 1
# Enter the Y-coordinate of the first point: 2
# Enter the X-coordinate of the second point: 3
# Enter the Y-coordinate of the second point: 4
